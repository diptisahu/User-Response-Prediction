# %%
import pandas as pd

# %%
data = pd.read_csv('data/fm_testing.csv')
data.head()
# Out:
#    Unnamed: 0  weekday  hour      IP  region  city  adexchange  domain  \
# 0     1261468        0    18  137643      22   252           1    3981
# 1     1301246        0    18    5372      31   343           2    3988
# 2      139698        0     2  188337       3    34           2     351
# 3     1633729        0    21  275140       7    78           2     117
# 4     1953258        1     1  356134      16   181           0    1232
#
#    slotid  slotwidth  slotheight  slotvisibility  slotformat  creative  \
# 0   21118          5           1               0           0         1
# 1   41496          5           1               0           0         1
# 2   41469          5           1               0           0        43
# 3   41455          0           6               0           0        29
# 4   41639          6           2               2           1        25
#
#    advertiser  useragent  slotprice  click
# 0           3         30          3      0
# ...

# %%
data = data.drop(columns=['Unnamed: 0'])
data.head()
# Out:
#    weekday  hour      IP  region  city  adexchange  domain  slotid  slotwidth  \
# 0        0    18  137643      22   252           1    3981   21118          5
# 1        0    18    5372      31   343           2    3988   41496          5
# 2        0     2  188337       3    34           2     351   41469          5
# 3        0    21  275140       7    78           2     117   41455          0
# 4        1     1  356134      16   181           0    1232   41639          6
#
#    slotheight  slotvisibility  slotformat  creative  advertiser  useragent  \
# 0           1               0           0         1           3         30
# 1           1               0           0         1           3         30
# 2           1               0           0        43           4         28
# 3           6               0           0        29           0         30
# 4           2               2           1        25           0         30
#
#    slotprice  click
# 0          3      0
# ...

# %%
cols = data.columns.tolist()
print(cols)
# Out:
# ['weekday', 'hour', 'IP', 'region', 'city', 'adexchange', 'domain', 'slotid', 'slotwidth', 'slotheight', 'slotvisibility', 'slotformat', 'creative', 'advertiser', 'useragent', 'slotprice', 'click']

# %%
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['click',
#  'weekday',
#  'hour',
#  'IP',
#  'region',
#  'city',
#  'adexchange',
#  'domain',
#  'slotid',
#  'slotwidth',
#  'slotheight',
#  'slotvisibility',
#  'slotformat',
#  'creative',
#  'advertiser',
#  'useragent',
#  'slotprice']

# %%
data = data[cols]

# %%
data.head()
# Out:
#    click  weekday  hour      IP  region  city  adexchange  domain  slotid  \
# 0      0        0    18  137643      22   252           1    3981   21118
# 1      0        0    18    5372      31   343           2    3988   41496
# 2      0        0     2  188337       3    34           2     351   41469
# 3      0        0    21  275140       7    78           2     117   41455
# 4      0        1     1  356134      16   181           0    1232   41639
#
#    slotwidth  slotheight  slotvisibility  slotformat  creative  advertiser  \
# 0          5           1               0           0         1           3
# 1          5           1               0           0         1           3
# 2          5           1               0           0        43           4
# 3          0           6               0           0        29           0
# 4          6           2               2           1        25           0
#
#    useragent  slotprice
# 0         30          3
# ...

# %%
data.to_csv('data/index_first_testing.csv', header = False, index=False)

# %%
out = pd.read_csv('output.txt')

# %%
out.value_counts()
# Out:
# 0
# 0    399999
# dtype: int64

# %%
data['weekday'].value_counts()
# Out:
# 0    364342
# 1     35658
# Name: weekday, dtype: int64
